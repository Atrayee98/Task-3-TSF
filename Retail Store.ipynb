# %% [markdown]
# # ATRAYEE DUTTA CHOWDHURY
# ## GRIPFEB21
# ## Data Science and Business Analytics Intern at The Sparks Foundation
# ## TASK 3 : EXPLANATORY DATA ANALYSIS- RETAIL
# ### Perform Explanatory Data Analysis on dataset 'SampleSuperstore'
# ### As a business manager, try to find out the weak areas where you can work to make profit
# ### What all business problems you can derive by exploring the data?

# %% [markdown]
# ### Importing important libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Importing the data

# %%
data=pd.read_csv("D:\SampleSuperstore.csv")
data.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %% [markdown]
# ### Analysing the data

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ##### The highest sale is of 22638.48
# ##### The maximum profit on a single sale is of 8399.976
# ##### The average quantity of items sold is 3

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# #### The data has no null values

# %% [markdown]
# ## Data Visualisation

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# ## Plotting a correlation matrix for the data

# %%
correlation=data.corr()
correlation
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(correlation, annot=True, xticklabels= True, yticklabels =True)
plt.show()

# %% [markdown]
# #### Here we observe that there is a moderate positive correlation between "Sales" and "Profit".
# #### On the other hand, there is a negative correlation between both "Sales" and "Discount" and "Profit" and "Discount"

# %% [markdown]
# ## Data Visualisation and Analysis of Different Columns

# %% [markdown]
# ### Analysis of Ship Mode column

# %%
data['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="Ship Mode",data=data)
plt.show()

# %% [markdown]
# #### The Standard class shipment mode is most preferred by the customers where as the Same Day shipment mode is least preferred

# %%
data.groupby(['Ship Mode','Segment'])["Segment"].count()
# Out:
# Ship Mode       Segment
# First Class     Consumer        769
#                 Corporate       485
#                 Home Office     284
# Same Day        Consumer        317
#                 Corporate       114
#                 Home Office     112
# Second Class    Consumer       1020
#                 Corporate       609
#                 Home Office     316
# Standard Class  Consumer       3085
#                 Corporate      1812
#                 Home Office    1071
# Name: Segment, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="Ship Mode",data=data,hue="Segment",palette="Set1")
plt.title("Distribution of various Shipping modes with respect to segments")
plt.show()

# %% [markdown]
# #### In all the four shipment modes, the Consumer Segment sale is highest

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="Ship Mode", hue="Category",data=data,palette="Set2")
plt.show()

# %% [markdown]
# #### In all the shipment modes,items belonging to the Office supplies category is being bought the most by customers and items belonging to technology category is bought the least

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="Ship Mode", hue="Region",data=data,palette="Set3")
plt.show()

# %% [markdown]
# ### Analysis of Segment column

# %%
plt.figure(figsize=(8,6))
explode=[0,0.01,0.01]
data['Segment'].value_counts().plot.pie(fontsize=20,autopct="%.1f%%",explode=explode)
plt.title("Different Segments")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="Segment", hue="Category",data=data,palette="Set2")
plt.title("Distribution of Various categories with respect to various segments")
plt.show()

# %% [markdown]
# #### In all the three segments, items belonging to office supplies are bought the most by customers and items belonging to technology are bought the least

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="Segment", hue="Region",data=data,palette="Set3")
plt.show()

# %% [markdown]
# ### Analysis of Region column

# %%
plt.figure(figsize=(8,6))
explode=[0.01,0.01,0.01,0.01]
data['Region'].value_counts().plot.pie(fontsize=16,autopct="%.1f%%",explode=explode)
plt.title("Distribution of number of sales in Different Regions")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Region',data=data,hue="Category",palette="Set1")
plt.title("Distrubution of Various Categories of Items in Different regions")
plt.show()

# %% [markdown]
# #### In all the four regions, items belonging to office segment are bought the most by customers and items belonging to Technology are bought the least by customers

# %% [markdown]
# ### Analysis of Category and Sub-Category columns

# %%
plt.figure(figsize=(8,6))
explode=[0,0.01,0.01]
data['Category'].value_counts().plot.pie(fontsize=16,autopct="%.1f%%",explode=explode)
plt.title("Distribution of number of sales of Different Categories")
plt.show()

# %%
data["Sub-Category"].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
plt.figure(figsize=(8,6))
sns.countplot(y="Sub-Category",data=data)
plt.title("Distribution of different Sub categories")
plt.show()

# %% [markdown]
# #### The highest number of items sold by the store are binders and the least number of items being sold by the store is Copiers

# %% [markdown]
# ## Analysis of the Sales and Profit columns

# %% [markdown]
# ### Ananlysis of sales and Profit with respect to different Shipment modes and Segments

# %%
plt.figure(figsize=(8,6))
sns.catplot( x="Ship Mode", y="Sales",col="Segment",data=data,kind="bar")
plt.show()

# %% [markdown]
# #### The sales for the Consumer segment is almost identical for all the different shipping modes.
# #### However for Corporate Segment the sales are highest for the same day shipping mode and it is highest for the first class shipping mode for home office segment

# %%
#As the postal column is of not much significance, so we drop it
df=data.drop(columns="Postal Code")

# %%
ship=df.groupby("Ship Mode").sum()
ship
# Out:
#                        Sales  Quantity  Discount       Profit
# Ship Mode
# First Class     3.514284e+05      5693    253.17   48969.8399
# Same Day        1.283631e+05      1960     82.75   15891.7589
# Second Class    4.591936e+05      7423    270.15   57446.6354
# Standard Class  1.358216e+06     22797    955.02  164088.7875

# %%
x1=ship.drop(columns=["Quantity","Discount"])
x1
# Out:
#                        Sales       Profit
# Ship Mode
# First Class     3.514284e+05   48969.8399
# Same Day        1.283631e+05   15891.7589
# Second Class    4.591936e+05   57446.6354
# Standard Class  1.358216e+06  164088.7875

# %%
x1.iloc[:,:3].plot(subplots=True, sharex=False, layout=(2,2),figsize=(10,10))

plt.show()

# %% [markdown]
# #### As is clear the sales and profit are highest for the Standard Class shipping mode and least for Same day

# %%
seg=df.groupby("Segment").sum()
x2=seg.drop(columns=["Quantity", "Discount"])
x2
# Out:
#                     Sales       Profit
# Segment
# Consumer     1.161401e+06  134119.2092
# Corporate    7.061464e+05   91979.1340
# Home Office  4.296531e+05   60298.6785

# %%
x2.iloc[:,:3].plot(subplots=True, sharex=False, layout=(2,2),figsize=(10,10))

plt.show()

# %% [markdown]
# #### As is evident the sales and profit are the most for the Consumer segment and least for Home Office segment

# %% [markdown]
# ### Ananlysis of sales and Profit with respect to different Regions

# %%
sns.catplot( x= "Region", y="Sales", kind="bar",data=data)
plt.title("Distribution of amount of Sales in different Regions")
plt.show()

# %%
sns.catplot( x= "Region", y="Profit", kind="bar",data=data)
plt.title("Distribution of Profit in different Regions")
plt.show()

# %% [markdown]
# #### As is evident the amount of sales as well as the profit are the most for the West region and least for the Central region

# %% [markdown]
# ### Ananlysis of sales and Profit with respect to different States

# %%
state=df.groupby("State").sum()
state_sale=state.sort_values(by=("Sales"),ascending=False)
plt.figure(figsize=(20,20))
plt.xticks(size=10)
plt.yticks(size=10)
sns.barplot(x="Sales", y=state_sale.index,data=state_sale)
plt.show()

# %% [markdown]
# #### We see the sales are very high for the states California, New York and Texas. However the sales are very low for states like Maine, West Virginia, North datoka

# %%
state_profit=state.sort_values(by=("Profit"),ascending=False)
plt.figure(figsize=(20,20))
plt.xticks(size=10)
plt.yticks(size=10)
sns.barplot(x="Profit", y=state_profit.index,data=state_profit)
plt.show()

# %% [markdown]
# #### The states California, New York, washington are the states giving high profit to the business.
# #### However the states Texas, Ohio ,Pennsylvania, Illinois, North Carolina, Colorado, Tennessee, Arizona, Florida , Oregon,Wyoming, West Virginia provide negative profit to the business.
# #### Although the states Texas, Ohio ,Pennsylvania, Illinois, North Carolina have quite good percentage of sale.

# %% [markdown]
# ### Let us look at these 5 states Texas, Ohio ,Pennsylvania, Illinois and North Carolina

# %%
s1=df.groupby(["State","Sub-Category"]).sum()
s2=s1.sort_values(by=["Sales", "Profit", "Discount"],ascending=False)
s2.loc['Texas'].sort_values(by=["Profit","Discount"],ascending=True)
# Out:
#                    Sales  Quantity  Discount      Profit
# Sub-Category
# Binders        9042.6760       626    122.40 -14705.0738
# Appliances     2407.8140       159     37.60  -6147.2225
# Furnishings    3766.7240       308     48.60  -3312.6786
# Machines      19546.2240        47      5.20  -2666.8434
# Chairs        26572.4480       235     18.30  -2515.6490
# Bookcases     14493.4588       105      8.64  -2391.1377
# Tables        15760.6610       118      9.90  -2216.6766
# Supplies       4516.7600        65      3.80   -837.2795
# Storage       15723.5840       309     16.60   -763.7054
# Fasteners       332.4640       108      4.80     80.7357
# Labels          583.6000        96      6.00    200.4020
# Art            2369.5280       259     14.20    316.3538
# Envelopes      2530.6480       105      6.00    848.1760
# Accessories   11328.5600       281     16.20   1105.8501
# Copiers        5639.8720        16      1.00   1629.9615
# ...

# %%
s2.loc['Ohio'].sort_values(by=["Profit","Discount"],ascending=True)
# Out:
#                   Sales  Quantity  Discount      Profit
# Sub-Category
# Machines       8978.238        39       5.6 -11770.9447
# Phones        14634.948       179      18.8  -2778.8578
# Tables         7887.114        49       6.4  -2715.3345
# Binders        1917.087       292      51.1  -1400.6681
# Bookcases      2077.705        32       4.0  -1359.0516
# Chairs        10145.702        79       6.9   -649.3542
# Storage        7264.440       123       7.4   -276.3364
# Supplies        478.808        22       1.4    -82.9029
# Labels          161.840        43       2.6     55.5222
# Fasteners       204.896        83       2.8     61.1197
# Art             840.104       140       7.8    103.2376
# Envelopes       562.000        38       2.4    194.6051
# Copiers        3839.934        11       1.6    446.9923
# Appliances     4807.536        96       4.6    486.2553
# Furnishings    4088.624       184       9.2    517.4191
# ...

# %%
s2.loc['Pennsylvania'].sort_values(by=["Profit","Discount"],ascending=True)
# Out:
#                   Sales  Quantity  Discount     Profit
# Sub-Category
# Binders        6266.058       331      68.6 -4570.9750
# Phones        19702.404       235      24.8 -3606.9276
# Bookcases      5230.755        44       5.0 -2896.7601
# Tables         8052.186        65       6.0 -2588.7538
# Machines       2133.717        20       4.9 -2219.2456
# Chairs        18724.174       153      10.8 -1993.4180
# Supplies       6710.208        34       2.4 -1459.5663
# Storage       11784.624       169       9.8 -1434.3118
# Fasteners       154.712        73       2.8    29.3222
# Art            1152.160       155       8.0   137.7581
# Labels          598.304       106       4.6   201.4208
# Furnishings    7347.816       225      12.8   282.2120
# Envelopes      1234.064        67       3.6   417.1003
# Appliances     4663.280        77       4.6   694.2150
# Paper          2378.304       236      13.2   813.0179
# Accessories    7299.280       141       9.0   898.9687
# ...

# %%
s2.loc['Illinois'].sort_values(by=["Profit","Discount"],ascending=True)
# Out:
#                   Sales  Quantity  Discount     Profit
# Sub-Category
# Binders        4538.546       327      64.0 -7204.3242
# Tables         6550.670        65       9.0 -4309.7447
# Furnishings    2877.976       193      34.2 -2631.9766
# Appliances      974.720        76      16.0 -2482.4187
# Chairs        14563.178       147      11.4 -1578.6955
# Bookcases      4282.698        43       3.0  -555.8726
# Storage        9080.328       151       9.4  -257.4584
# Supplies        178.152        26       1.4    13.4273
# Fasteners       141.336        50       2.6    43.9949
# Labels          224.872        48       2.6    77.4622
# Envelopes       384.104        22       1.6   132.5294
# Art             930.032       149       7.4   138.9541
# Machines       3756.305        12       1.5   326.0395
# Accessories    5535.696       145       6.6   981.8644
# Paper          3455.816       246      12.0  1183.6766
# Phones        16771.784       131       8.4  1682.6887
# ...

# %%
s2.loc['North Carolina'].sort_values(by=["Profit","Discount"],ascending=True)
# Out:
#                   Sales  Quantity  Discount     Profit
# Sub-Category
# Machines      12620.655        11       2.0 -5384.8086
# Tables         9681.732        49       3.2 -3684.2539
# Binders        2562.321       185      25.2 -2007.8254
# Bookcases       959.056        19       0.8   -97.9780
# Storage        3438.088        54       3.2   -86.2088
# Supplies        302.040        16       1.2   -27.9803
# Fasteners        66.336        22       0.8    21.8637
# Labels          229.424        35       1.8    75.8684
# Art             603.392       107       5.2    78.9165
# Copiers         959.968         4       0.2   119.9960
# Envelopes       431.144        20       1.2   139.7061
# Chairs         2723.592        36       2.2   142.7239
# Furnishings    1791.104        70       3.8   153.0447
# Appliances     4137.552        57       3.4   485.6746
# Accessories    3506.632        72       3.8   821.0744
# Phones         8995.864        87       5.4   860.4342
# ...

# %% [markdown]
# ####  For the above 5 states , we see that sale of Binders and Machine contribute highly to the negative profit.
# #### One of the reasons may be that a very high discount percentage is available for binders in all the 5 states.
# #### Overall the profit is mostly negative for those items where discount rate is quite high

# %% [markdown]
# ## As California has the highest sale and profit, lets look into its stats

# %%
s2.loc['California'].sort_values(by=["Sales","Profit"],ascending=False)
# Out:
#                    Sales  Quantity  Discount      Profit
# Sub-Category
# Phones        67964.5360       691      34.4   6309.1197
# Chairs        63079.3680       466      26.0   2435.9715
# Tables        45430.2320       281      14.2   -303.5580
# Storage       45112.2900       637       0.0   7204.1372
# Accessories   37255.0100       568       0.0  11095.6565
# Machines      29492.0160        86       4.6   4175.4087
# Binders       28473.1680      1057      55.2  10002.1537
# Bookcases     27558.5215       198       7.8   1418.9915
# Copiers       24559.5200        60       3.4   7889.8519
# Appliances    24175.9200       346       0.0   6992.2318
# Furnishings   19996.4800       751       0.0   5611.5606
# Paper         16757.9500      1091       0.0   7977.5395
# Supplies      15720.9500       145       0.0    862.2003
# Art            5495.6600       644       0.0   1614.8365
# Envelopes      3237.3400       149       0.0   1529.4161
# ...

# %% [markdown]
# #### For California, sales of Phones is highest, followed by Chairs .
# #### Although Copiers, Appliances, Paper and Furnishing items contriute quite highly to the profit in California, their sales are not much high.
# #### So the store should go for more advertisements of Copiers, Appliances, Paper and Furnishing items
# #### There is a negative discount for sale of Tables. Reducing the discount rate on Tables might help increasing the profit

# %% [markdown]
# ## Ananlysis of sales and Profit with respect to different Categories

# %%
sns.catplot(x="Category", y="Sales",data=data,kind="bar")
plt.title("Distribution of amount of Sales vs Category")
plt.show()

# %%
cat=data.groupby(["Category"]).sum()
cat
# Out:
#                  Postal Code        Sales  Quantity  Discount       Profit
# Category
# Furniture          118196026  741999.7953      8028    368.89   18451.2728
# Office Supplies    330772872  719047.0320     22906    947.80  122490.8008
# Technology         102603754  836154.0330      6939    244.40  145454.9481

# %%
sns.catplot(x="Category", y="Profit",data=data,kind="bar")
plt.title("Distribution of Profit vs Category")
plt.show()

# %% [markdown]
# #### As is evident, both the amount of sales and profit is maximum for technology. However for the category furniture, sale is quite high yet profit is least for it

# %% [markdown]
# ### Ananlysis of sales and Profit with respect to different Sub Categories

# %%
sub_cat=df.groupby(["Sub-Category"]).sum()
sub_cat
# Out:
#                     Sales  Quantity  Discount      Profit
# Sub-Category
# Accessories   167380.3180      2976     60.80  41936.6357
# Appliances    107532.1610      1729     77.60  18138.0054
# Art            27118.7920      3000     59.60   6527.7870
# Binders       203412.7330      5974    567.00  30221.7633
# Bookcases     114879.9963       868     48.14  -3472.5560
# Chairs        328449.1030      2356    105.00  26590.1663
# Copiers       149528.0300       234     11.00  55617.8249
# Envelopes      16476.4020       906     20.40   6964.1767
# Fasteners       3024.2800       914     17.80    949.5182
# Furnishings    91705.1640      3563    132.40  13059.1436
# Labels         12486.3120      1400     25.00   5546.2540
# Machines      189238.6310       440     35.20   3384.7569
# Paper          78479.2060      5178    102.60  34053.5693
# Phones        330007.0540      3289    137.40  44515.7306
# Storage       223843.6080      3158     63.20  21278.8264
# ...

# %%
sub_sale=sub_cat.sort_values(by=("Sales"),ascending=False)
plt.figure(figsize=(10,10))
plt.xticks(size=10)
plt.yticks(size=10)
sns.barplot(x="Sales", y=sub_sale.index,data=sub_sale)
plt.show()

# %% [markdown]
# #### As is evident sale is highest for Phones and almost equally high for chairs.
# #### However the sale is very low for fasteners and labels

# %%
sub_profit=sub_cat.sort_values(by=("Profit"),ascending=False)
plt.figure(figsize=(10,10))
plt.xticks(size=10)
plt.yticks(size=10)
sns.barplot(x="Profit", y=sub_profit.index,data=sub_profit)
plt.show()

# %% [markdown]
# #### As is evident the profit is highest for copiers followed by phones.
# #### However the business faces a negative profit for tables, Bookcases and Supplies

# %%
d1=sub_cat.sort_values(by=["Profit","Discount"], ascending =True)
d1
# Out:
#                     Sales  Quantity  Discount      Profit
# Sub-Category
# Tables        206965.5320      1241     83.35 -17725.4811
# Bookcases     114879.9963       868     48.14  -3472.5560
# Supplies       46673.5380       647     14.60  -1189.0995
# Fasteners       3024.2800       914     17.80    949.5182
# Machines      189238.6310       440     35.20   3384.7569
# Labels         12486.3120      1400     25.00   5546.2540
# Art            27118.7920      3000     59.60   6527.7870
# Envelopes      16476.4020       906     20.40   6964.1767
# Furnishings    91705.1640      3563    132.40  13059.1436
# Appliances    107532.1610      1729     77.60  18138.0054
# Storage       223843.6080      3158     63.20  21278.8264
# Chairs        328449.1030      2356    105.00  26590.1663
# Binders       203412.7330      5974    567.00  30221.7633
# Paper          78479.2060      5178    102.60  34053.5693
# Accessories   167380.3180      2976     60.80  41936.6357
# ...

# %% [markdown]
# #### The profit is negative for Tables, Bookcases and supplies .
# #### A major reason can be that discount for these sub-categories is quite high
# #### So lowering the discount rate might help in increasing the profit

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### 1. The dataset is about a Superstore's Sale
# #### 2.The data has 9994 entries and 13 columns
# #### 3. The columns are Ship Mode, Segment, Country, City, State, Postal Code,Region, Category, Sub-Category, Sales,Quantity,Discount,Profit
# #### 4. Standard Class is the most preferred mode of shipment
# #### 5. The segment Consumer has highest number of customers and the customers of consumer segment are mostly from the West and East regions
# #### 6.The store has least number of customers from Home Office segment and hence the sale and profit for this segment is the least. The store should try to attract more customers from this segment
# #### 7. The store has most of the Customers from the West region and the least from the south region
# #### 8.However the amount of sale is highest for West region and almost equally high in the East region.
# #### 9.The profit earned by the store is highest for West Region
# #### 10.The amount of sale as well as profit is least for Central region. Hence the store should try to attract more customers from Central region
# #### 11.We see the  amount of sales are very high for the states California, New York and Texas. However the sales are very low for states like Maine, West Virginia, North datoka
# #### 12.The states California, New York, Washington are the states giving high profit to the business.
# #### 13.However the states Texas, Ohio ,Pennysylvania, Illinois, North Carolina, Colorado, Tennessee, Arizona, Florida , Oregon,Wyoming, West Virginia provide negative profit to the business.
# #### 14.Although the states Texas, Ohio ,Pennysylvania, Illinois, North Carolina have quite good percentage of sale, the profit is negative in these states
# #### 15.For the above 5 states , we see that sale of Binders and Machine contribute highly to the negative profit.
# #### 16.One of the reasons may be that a very high discount percentage is available for binders in all the 5 states.
# #### 17.Overall the profit is mostly negative for those items where discount rate is quite high.
# #### 18.For California, sales of Phones is highest, followed by Chairs .
# #### 19.Although Copiers, Appliances, Paper and Furnishing items contriute quite highly to the profit in California, their sales are not much high.
# #### 20.So the store should go for more advertisements of Copiers, Appliances, Paper and Furnishing items in California
# #### 21.There is a negative discount for sale of Tables. Reducing the discount rate on Tables might help increasing the profit in California
# #### 22.Although the number of sales of items belonging to Office Supplies is highest, profit is highest for items belonging to Technology Category
# #### 23.So the store should try to increase its profit margin for Office Supplies item as well as try to increase its sale of Technology items by allowing some discounts
# #### 24.The amount of sale is highest for Phones and almost equally high for chairs.
# #### 25.However the sale is very low for fasteners and labels
# #### 26.The profit is highest for copiers followed by phones.
# #### 27.However the business faces a negative profit for tables, Bookcases and Supplies
# #### 28.A major reason can be that discount for these sub-categories is quite high
# #### 29.So lowering the discount rate might help in increasing the profit

# %% [markdown]
# # Thank you
